# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('nyc-zip-codes.csv')

# %%
df
# Out:
#            Borough              Neighborhood  ZipCode
# 0            Bronx             Central Bronx    10453
# 1            Bronx             Central Bronx    10457
# 2            Bronx             Central Bronx    10460
# 3            Bronx    Bronx Park and Fordham    10458
# 4            Bronx    Bronx Park and Fordham    10467
# ..             ...                       ...      ...
# 173  Staten Island               South Shore    10312
# 174  Staten Island  Stapleton and St. George    10301
# 175  Staten Island  Stapleton and St. George    10304
# 176  Staten Island  Stapleton and St. George    10305
# 177  Staten Island                Mid-Island    10314
#
# [178 rows x 3 columns]

# %%
cdta_mapping = {
    "Bronx": {
        "Bronx Park and Fordham": "BX07",
        "Central Bronx": "BX06",
        "High Bridge and Morrisania": "BX05",
        "Hunts Point and Mott Haven": "BX01",
        "Kingsbridge and Riverdale": "BX08",
        "Northeast Bronx": "BX12",
        "Southeast Bronx": "BX09"
    },
    "Brooklyn": {
        "Borough Park": "BK12",
        "Bushwick and Williamsburg": "BK04",
        "Canarsie and Flatlands": "BK18",
        "Central Brooklyn": "BK08",
        "East New York and New Lots": "BK05",
        "Flatbush": "BK14",
        "Greenpoint": "BK01",
        "Northwest Brooklyn": "BK02",
        "Southern Brooklyn": "BK15",
        "Southwest Brooklyn": "BK10",
        "Sunset Park": "BK07"
    },
    "Manhattan": {
        "Central Harlem": "MN10",
        "Chelsea and Clinton": "MN04",
        "East Harlem": "MN11",
        "Gramercy Park and Murray Hill": "MN06",
        "Greenwich Village and Soho": "MN02",
        "Inwood and Washington Heights": "MN12",
        "Lower East Side": "MN03",
        "Lower Manhattan": "MN01",
        "Upper East Side": "MN08",
        "Upper West Side": "MN07"
    },
    "Queens": {
        "Central Queens": "QN08",
        "Jamaica": "QN12",
        "North Queens": "QN07",
        "Northeast Queens": "QN11",
        "Northwest Queens": "QN01",
        "Rockaways": "QN14",
        "Southeast Queens": "QN13",
        "Southwest Queens": "QN09",
        "West Central Queens": "QN05",
        "West Queens": "QN04"
    },
    "Staten Island": {
        "Mid-Island": "SI02",
        "Port Richmond": "SI01",
        "South Shore": "SI03",
        "Stapleton and St. George": "SI01"
    }
}

# %%
# Map CDTA
df['CDTA'] = df.apply(lambda row: cdta_mapping[row['Borough']][row['Neighborhood']], axis=1)

# %%
# Group by Borough, Neighborhood, and CDTA
grouped = df.groupby(['Borough', 'Neighborhood', 'CDTA'])['ZipCode'].unique().reset_index()

# %%
# Convert to list
grouped['ZipCode'] = grouped['ZipCode'].apply(lambda x: x.tolist())

# %%
grouped
# Out:
#           Borough                   Neighborhood  CDTA  \
# 0           Bronx         Bronx Park and Fordham  BX07
# 1           Bronx                  Central Bronx  BX06
# 2           Bronx     High Bridge and Morrisania  BX05
# 3           Bronx     Hunts Point and Mott Haven  BX01
# 4           Bronx      Kingsbridge and Riverdale  BX08
# 5           Bronx                Northeast Bronx  BX12
# 6           Bronx                Southeast Bronx  BX09
# 7        Brooklyn                   Borough Park  BK12
# 8        Brooklyn      Bushwick and Williamsburg  BK04
# 9        Brooklyn         Canarsie and Flatlands  BK18
# 10       Brooklyn               Central Brooklyn  BK08
# 11       Brooklyn     East New York and New Lots  BK05
# 12       Brooklyn                       Flatbush  BK14
# 13       Brooklyn                     Greenpoint  BK01
# 14       Brooklyn             Northwest Brooklyn  BK02
# 15       Brooklyn              Southern Brooklyn  BK15
# 16       Brooklyn             Southwest Brooklyn  BK10
# 17       Brooklyn                    Sunset Park  BK07
# 18      Manhattan                 Central Harlem  MN10
# 19      Manhattan            Chelsea and Clinton  MN04
# 20      Manhattan                    East Harlem  MN11
# 21      Manhattan  Gramercy Park and Murray Hill  MN06
# 22      Manhattan     Greenwich Village and Soho  MN02
# 23      Manhattan  Inwood and Washington Heights  MN12
# 24      Manhattan                Lower East Side  MN03
# 25      Manhattan                Lower Manhattan  MN01
# 26      Manhattan                Upper East Side  MN08
# 27      Manhattan                Upper West Side  MN07
# 28         Queens                 Central Queens  QN08
# 29         Queens                        Jamaica  QN12
# 30         Queens                   North Queens  QN07
# 31         Queens               Northeast Queens  QN11
# 32         Queens               Northwest Queens  QN01
# 33         Queens                      Rockaways  QN14
# 34         Queens               Southeast Queens  QN13
# 35         Queens               Southwest Queens  QN09
# 36         Queens            West Central Queens  QN05
# 37         Queens                    West Queens  QN04
# 38  Staten Island                     Mid-Island  SI02
# 39  Staten Island                  Port Richmond  SI01
# 40  Staten Island                    South Shore  SI03
# 41  Staten Island       Stapleton and St. George  SI01
#
#                                               ZipCode
# 0                               [10458, 10467, 10468]
# 1                               [10453, 10457, 10460]
# 2                               [10451, 10452, 10456]
# 3                        [10454, 10455, 10459, 10474]
# 4                                      [10463, 10471]
# 5                        [10466, 10469, 10470, 10475]
# 6          [10461, 10462, 10464, 10465, 10472, 10473]
# 7                        [11204, 11218, 11219, 11230]
# 8                               [11206, 11221, 11237]
# 9                               [11234, 11236, 11239]
# 10                [11212, 11213, 11216, 11233, 11238]
# 11                                     [11207, 11208]
# 12                       [11203, 11210, 11225, 11226]
# 13                                     [11211, 11222]
# 14                [11201, 11205, 11215, 11217, 11231]
# 15                       [11223, 11224, 11229, 11235]
# 16                              [11209, 11214, 11228]
# 17                                     [11220, 11232]
# 18                [10026, 10027, 10030, 10037, 10039]
# 19         [10001, 10011, 10018, 10019, 10020, 10036]
# 20                                     [10029, 10035]
# 21                       [10010, 10016, 10017, 10022]
# 22                              [10012, 10013, 10014]
# 23                [10031, 10032, 10033, 10034, 10040]
# 24                              [10002, 10003, 10009]
# 25         [10004, 10005, 10006, 10007, 10038, 10280]
# 26         [10021, 10028, 10044, 10065, 10075, 10128]
# 27                              [10023, 10024, 10025]
# 28                              [11365, 11366, 11367]
# 29  [11412, 11423, 11432, 11433, 11434, 11435, 11436]
# 30  [11354, 11355, 11356, 11357, 11358, 11359, 11360]
# 31                       [11361, 11362, 11363, 11364]
# 32         [11101, 11102, 11103, 11104, 11105, 11106]
# 33         [11691, 11692, 11693, 11694, 11695, 11697]
# 34  [11004, 11005, 11411, 11413, 11422, 11426, 114...
# 35  [11414, 11415, 11416, 11417, 11418, 11419, 114...
# 36                       [11374, 11375, 11379, 11385]
# 37  [11368, 11369, 11370, 11372, 11373, 11377, 11378]
# 38                                            [10314]
# 39                              [10302, 10303, 10310]
# 40                [10306, 10307, 10308, 10309, 10312]
# 41                              [10301, 10304, 10305]

# %%
result = {}
for borough in grouped['Borough'].unique():
    borough_data = grouped[grouped['Borough'] == borough]
    result[borough] = {}
    for neighborhood in borough_data['Neighborhood'].unique():
        neighborhood_data = borough_data[borough_data['Neighborhood'] == neighborhood]
        result[borough][neighborhood] = {}
        for _, row in neighborhood_data.iterrows():
            result[borough][neighborhood][row['CDTA']] = row['ZipCode']

# %%
# Save 
with open('borough_neighbourhood.json', 'w') as f:
    json.dump(result, f, indent=2)
