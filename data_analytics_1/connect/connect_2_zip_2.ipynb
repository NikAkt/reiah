# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
arrest_data = pd.read_csv('data/cleaned_arrest_data.csv')
business_data = pd.read_csv('data/cleaned_business_data.csv')
demographic_data = pd.read_csv('data/cleaned_demographic_data.csv')
noise_data = pd.read_csv('data/cleaned_noise_data.csv')
poi_data = pd.read_csv('data/cleaned_poi.csv')
taxi_data = pd.read_csv('data/cleaned_taxi_data.csv')

# %%
# Arrest data
arrest_data = arrest_data.groupby('ZipCode')['AvgMonthlyArrests'].mean().reset_index()

# %%
# Business Data
business_data = business_data.pivot(index='ZipCode', columns='BusinessType', values='Count').reset_index()
business_data = business_data.fillna(0)
business_data['TotalBusinesses'] = business_data.sum(axis=1)
business_data['BusinessTypeCount'] = (business_data.set_index('ZipCode') > 0).sum(axis=1).values

# %%
# Demographic data
demographic_data = demographic_data.groupby('ZipCode').agg({
    'Population': 'mean',
    'PopulationDensity': 'mean',
    'MedianHouseholdIncome': 'mean',
    'DiversityIndex': 'first',
    'FamilyHousehold': 'mean',
    'SingleHousehold': 'mean'
}).reset_index()

# %%
# Noise data
noise_data = noise_data.groupby('ZipCode')['AvgMonthlyNoiseComplaints'].mean().reset_index()

# %%
# Places of interest data
poi_data = poi_data.groupby('zipcode').agg({
    'cultural_facility': 'sum',
    'education_facility': 'sum',
    'health_services': 'sum',
    'public_safety': 'sum',
    'recreational_facility': 'sum',
    'religious_institution': 'sum',
    'transportation_facility': 'sum'
}).reset_index()
poi_data = poi_data.rename(columns={'zipcode': 'ZipCode'})

# %%
# Taxi data - use yearly counts for liveliness
taxi_data['date'] = pd.to_datetime(taxi_data['date'])
taxi_data['year'] = taxi_data['date'].dt.year
taxi_data = taxi_data.groupby(['zipcode', 'year'])['passenger_count'].sum().reset_index()
taxi_data = taxi_data.groupby('zipcode')['passenger_count'].mean().reset_index()  
taxi_data = taxi_data.rename(columns={'zipcode': 'ZipCode'})

# %%
# Merge datasets
merged_data = demographic_data.merge(arrest_data, on='ZipCode', how='left')
merged_data = merged_data.merge(business_data, on='ZipCode', how='left')
merged_data = merged_data.merge(noise_data, on='ZipCode', how='left')
merged_data = merged_data.merge(poi_data, on='ZipCode', how='left')
merged_data = merged_data.merge(taxi_data, on='ZipCode', how='left')

# %%
merged_data = merged_data.dropna(subset=['Population'])

# %%
merged_data.isnull().sum()
# Out:
# ZipCode                            0
# Population                         0
# PopulationDensity                  0
# MedianHouseholdIncome              0
# DiversityIndex                     0
# FamilyHousehold                    0
# SingleHousehold                    0
# AvgMonthlyArrests                  7
# entertainment_and_recreation       0
# financial_services                 0
# food_and_beverage                  0
# home_services                      0
# parking_and_automotive_services    0
# professional_services              0
# retail_services                    0
# transportation                     0
# TotalBusinesses                    0
# BusinessTypeCount                  0
# AvgMonthlyNoiseComplaints          0
# cultural_facility                  0
# education_facility                 0
# health_services                    0
# public_safety                      0
# recreational_facility              0
# religious_institution              0
# transportation_facility            0
# passenger_count                    0
# dtype: int64

# %%
# Impute AvgMonthlyArrests with median
merged_data['AvgMonthlyArrests'] = merged_data['AvgMonthlyArrests'].fillna(merged_data['AvgMonthlyArrests'].median())

# %%
# Impute places of interest data with 0
poi_columns = ['cultural_facility', 'education_facility', 'health_services', 
               'public_safety', 'recreational_facility', 'religious_institution', 'transportation_facility']
merged_data[poi_columns] = merged_data[poi_columns].fillna(0)

# %%
# Feature engineering
merged_data['BusinessDensity'] = merged_data['TotalBusinesses'] / merged_data['Population']
merged_data['ArrestsPerCapita'] = merged_data['AvgMonthlyArrests'] / merged_data['Population']
merged_data['NoiseComplaintsPerCapita'] = merged_data['AvgMonthlyNoiseComplaints'] / merged_data['Population']
merged_data['FamilyHouseholdRatio'] = merged_data['FamilyHousehold'] / (merged_data['FamilyHousehold'] + merged_data['SingleHousehold'])

facility_columns = ['cultural_facility', 'education_facility', 'health_services', 'public_safety', 'recreational_facility', 'religious_institution', 'transportation_facility']
for facility in facility_columns:
    merged_data[f'{facility}_density'] = merged_data[facility] / merged_data['Population']

# %%
merged_data['AmenityScore'] = merged_data[facility_columns].sum(axis=1)
merged_data['SafetyScore'] = (1 / (merged_data['ArrestsPerCapita'] + 1)) + merged_data['public_safety_density']  # Higher score means safer
merged_data['QuietScore'] = 1 / (merged_data['NoiseComplaintsPerCapita'] + 1)  # Higher score means quieter
merged_data['FamilyFriendlinessScore'] = merged_data['FamilyHouseholdRatio']
merged_data['BusinessEnvironmentScore'] = merged_data['BusinessTypeCount']

# %%
# Bin continuous variables
merged_data['IncomeCategory'] = pd.qcut(merged_data['MedianHouseholdIncome'], q=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])
merged_data['PopulationDensityCategory'] = pd.qcut(merged_data['PopulationDensity'], q=5, labels=['Very Low', 'Low', 'Medium', 'High', 'Very High'])

# %%
scaler = MinMaxScaler()
numeric_columns = merged_data.select_dtypes(include=[np.number]).columns
numeric_columns = numeric_columns.drop(['ZipCode', 'passenger_count'])
merged_data[numeric_columns] = scaler.fit_transform(merged_data[numeric_columns])

# %%
# Separately scale the passenger_count (LivelinessScore)
merged_data['LivelinessScore'] = np.log1p(merged_data['passenger_count'])
merged_data['LivelinessScore'] = (merged_data['LivelinessScore'] - merged_data['LivelinessScore'].min()) / (merged_data['LivelinessScore'].max() - merged_data['LivelinessScore'].min())

# %%
# Map latitudes and longitudes to zip codes 
us_zip_codes = pd.read_csv('us_zip_codes copy')

# %%
# Rename columns to match your data
us_zip_codes = us_zip_codes.rename(columns={'ZIP': 'ZipCode', 'LAT': 'Latitude', 'LNG': 'Longitude'})

# %%
merged_data = merged_data.merge(us_zip_codes[['ZipCode', 'Latitude', 'Longitude']], on='ZipCode', how='left')

# %%
property_data = pd.read_csv('data/cleaned_property_data.csv')

# %%
# Forgot to add borough
borough_info = property_data[['ZIPCODE', 'BOROUGH']].drop_duplicates()
merged_data = merged_data.merge(borough_info, left_on='ZipCode', right_on='ZIPCODE', how='left')
merged_data.drop('ZIPCODE', axis=1, inplace=True)

# %%
merged_data
# Out:
#      ZipCode  Population  PopulationDensity  MedianHouseholdIncome  \
# 0      10001    0.178460           0.229401               0.291567
# 1      10002    0.736222           0.641051               0.061627
# 2      10003    0.501438           0.673463               0.343147
# 3      10004    0.011866           0.029665               0.517659
# 4      10005    0.049286           0.672479               0.495625
# ..       ...         ...                ...                    ...
# 173    11691    0.538534           0.139689               0.091007
# 174    11692    0.154765           0.121295               0.109729
# 175    11693    0.093503           0.074831               0.143973
# 176    11694    0.172042           0.095858               0.269134
# 177    11697    0.021022           0.003814               0.319875
#
#      DiversityIndex  FamilyHousehold  SingleHousehold  AvgMonthlyArrests  \
# 0          0.657538         0.116622         0.264750           0.125995
# 1          0.855261         0.735630         0.642147           0.414068
# 2          0.453662         0.278357         0.768360           0.422632
# 3          0.544463         0.009048         0.010225           0.200071
# 4          0.553878         0.023407         0.089543           0.204854
# ..              ...              ...              ...                ...
# 173        0.803618         0.528865         0.262181           0.300396
# 174        0.632334         0.166632         0.055123           0.081839
# 175        0.744671         0.110811         0.048440           0.153579
# 176        0.358441         0.186221         0.126599           0.035458
# 177        0.000000         0.031334         0.000000           0.000801
#
#      entertainment_and_recreation  financial_services  ...  SafetyScore  \
# 0                        0.260870             0.15625  ...     0.944887
# 1                        0.228261             0.09375  ...     0.957731
# 2                        0.380435             0.00000  ...     0.933428
# 3                        0.032609             0.53125  ...     0.382492
# 4                        0.065217             0.12500  ...     0.728680
# ..                            ...                 ...  ...          ...
# 173                      0.010870             0.00000  ...     0.956775
# 174                      0.010870             0.00000  ...     0.962270
# 175                      0.076087             0.03125  ...     0.885879
# 176                      0.043478             0.00000  ...     0.990415
# 177                      0.010870             0.00000  ...     0.997842
#
#      QuietScore  FamilyFriendlinessScore  BusinessEnvironmentScore  \
# 0      0.297030                 0.089688                  0.833333
# 1      0.614479                 0.440576                  0.833333
# 2      0.561235                 0.038836                  0.500000
# 3      0.003576                 0.165744                  0.833333
# 4      0.528810                 0.003927                  0.666667
# ..          ...                      ...                       ...
# 173    0.865858                 0.699973                  0.500000
# 174    0.847654                 0.763476                  0.666667
# 175    0.779566                 0.608474                  0.666667
# 176    0.837260                 0.502956                  0.500000
# 177    0.991952                 0.564180                  0.333333
#
#      IncomeCategory  PopulationDensityCategory  LivelinessScore   Latitude  \
# 0              High                     Medium         0.977530  40.750633
# 1          Very Low                  Very High         0.847983  40.715775
# 2         Very High                  Very High         0.930073  40.731829
# 3         Very High                   Very Low         0.773701  40.688630
# 4         Very High                  Very High         0.724375  40.706027
# ..              ...                        ...              ...        ...
# 173        Very Low                        Low         0.264675  40.601278
# 174             Low                        Low         0.166121  40.594095
# 175             Low                   Very Low         0.230819  40.590692
# 176            High                   Very Low         0.233822  40.578270
# 177       Very High                   Very Low         0.158389  40.555688
#
#      Longitude    BOROUGH
# 0   -73.997177  Manhattan
# 1   -73.986212  Manhattan
# 2   -73.989181  Manhattan
# 3   -74.018244  Manhattan
# 4   -74.008835  Manhattan
# ..         ...        ...
# 173 -73.761651     Queens
# 174 -73.792896     Queens
# 175 -73.809749     Queens
# 176 -73.844762     Queens
# 177 -73.920663     Queens
#
# [178 rows x 49 columns]

# %%
# Save processed data
merged_data.to_csv('processed_data_by_zipcode.csv', index=False)

# %% [markdown]
# # Check scores

# %%
# Group by Borough and list zipcodes with their scores
borough_groups = merged_data.groupby('ZipCode')

for borough, group in borough_groups:
    print(f"\nBorough: {borough}")
    print(f"{'ZipCode':<10} {'LivelinessScore':<20} {'BusinessEnvironmentScore':<25}")
    print("-" * 55)
    for _, row in group.iterrows():
        zipcode = row['ZipCode']
        liveliness_score = row['LivelinessScore']
        business_env_score = row['BusinessEnvironmentScore']
        print(f"{zipcode:<10} {liveliness_score:<20.2f} {business_env_score:<25.2f}")
# Out:
# Borough: 10001
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10001      0.98                 0.83
#
# Borough: 10002
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10002      0.85                 0.83
#
# Borough: 10003
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10003      0.93                 0.50
#
# Borough: 10004
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10004      0.77                 0.83
#
# Borough: 10005
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10005      0.72                 0.67
#
# Borough: 10006
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10006      0.78                 0.67
#
# Borough: 10007
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10007      0.80                 0.67
#
# Borough: 10009
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10009      0.87                 0.50
#
# Borough: 10010
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10010      0.93                 0.83
#
# Borough: 10011
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10011      0.95                 0.83
#
# Borough: 10012
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10012      0.81                 0.67
#
# Borough: 10013
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10013      0.86                 0.83
#
# Borough: 10014
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10014      0.95                 1.00
#
# Borough: 10016
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10016      0.94                 0.83
#
# Borough: 10017
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10017      0.96                 0.83
#
# Borough: 10018
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10018      0.95                 1.00
#
# Borough: 10019
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10019      1.00                 0.83
#
# Borough: 10021
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10021      0.97                 0.67
#
# Borough: 10022
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10022      1.00                 1.00
#
# Borough: 10023
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10023      0.88                 0.83
#
# Borough: 10024
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10024      0.92                 0.67
#
# Borough: 10025
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10025      0.87                 0.83
#
# Borough: 10026
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10026      0.84                 0.67
#
# Borough: 10027
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10027      0.77                 0.83
#
# Borough: 10028
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10028      0.91                 0.67
#
# Borough: 10029
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10029      0.91                 1.00
#
# Borough: 10030
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10030      0.63                 0.67
#
# Borough: 10031
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10031      0.63                 0.83
#
# Borough: 10032
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10032      0.65                 0.83
#
# Borough: 10033
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10033      0.58                 0.83
#
# Borough: 10034
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10034      0.58                 0.83
#
# Borough: 10035
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10035      0.72                 0.83
#
# Borough: 10036
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10036      0.99                 0.83
#
# Borough: 10037
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10037      0.68                 0.83
#
# Borough: 10038
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10038      0.82                 0.83
#
# Borough: 10039
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10039      0.71                 0.67
#
# Borough: 10040
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10040      0.49                 0.83
#
# Borough: 10044
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10044      0.32                 0.33
#
# Borough: 10065
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10065      0.92                 1.00
#
# Borough: 10069
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10069      0.85                 0.33
#
# Borough: 10075
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10075      0.98                 0.83
#
# Borough: 10128
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10128      0.92                 0.67
#
# Borough: 10280
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10280      0.78                 0.50
#
# Borough: 10282
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10282      0.76                 0.33
#
# Borough: 10301
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10301      0.19                 0.83
#
# Borough: 10302
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10302      0.09                 0.67
#
# Borough: 10303
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10303      0.11                 0.83
#
# Borough: 10304
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10304      0.20                 0.67
#
# Borough: 10305
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10305      0.14                 0.67
#
# Borough: 10306
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10306      0.17                 0.83
#
# Borough: 10307
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10307      0.00                 0.33
#
# Borough: 10308
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10308      0.03                 0.67
#
# Borough: 10309
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10309      0.02                 0.50
#
# Borough: 10310
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10310      0.09                 0.67
#
# Borough: 10312
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10312      0.13                 0.83
#
# Borough: 10314
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10314      0.17                 0.83
#
# Borough: 10451
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10451      0.48                 0.83
#
# Borough: 10452
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10452      0.43                 0.83
#
# Borough: 10453
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10453      0.37                 0.83
#
# Borough: 10454
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10454      0.37                 0.83
#
# Borough: 10455
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10455      0.41                 0.83
#
# Borough: 10456
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10456      0.45                 0.83
#
# Borough: 10457
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10457      0.44                 0.83
#
# Borough: 10458
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10458      0.39                 0.83
#
# Borough: 10459
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10459      0.39                 0.67
#
# Borough: 10460
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10460      0.39                 0.83
#
# Borough: 10461
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10461      0.41                 0.83
#
# Borough: 10462
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10462      0.41                 0.83
#
# Borough: 10463
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10463      0.42                 0.83
#
# Borough: 10464
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10464      0.27                 0.33
#
# Borough: 10465
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10465      0.33                 0.67
#
# Borough: 10466
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10466      0.34                 0.67
#
# Borough: 10467
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10467      0.41                 0.83
#
# Borough: 10468
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10468      0.38                 0.83
#
# Borough: 10469
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10469      0.39                 0.83
#
# Borough: 10470
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10470      0.26                 0.50
#
# Borough: 10471
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10471      0.38                 0.67
#
# Borough: 10472
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10472      0.36                 0.83
#
# Borough: 10473
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10473      0.34                 0.67
#
# Borough: 10474
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10474      0.38                 0.33
#
# Borough: 10475
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 10475      0.29                 0.67
#
# Borough: 11004
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11004      0.22                 0.67
#
# Borough: 11005
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11005      0.15                 0.00
#
# Borough: 11101
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11101      0.65                 0.83
#
# Borough: 11102
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11102      0.60                 0.83
#
# Borough: 11103
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11103      0.61                 0.83
#
# Borough: 11104
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11104      0.52                 0.83
#
# Borough: 11105
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11105      0.56                 0.83
#
# Borough: 11106
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11106      0.59                 0.67
#
# Borough: 11109
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11109      0.51                 0.00
#
# Borough: 11201
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11201      0.65                 0.67
#
# Borough: 11203
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11203      0.49                 0.83
#
# Borough: 11204
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11204      0.37                 0.67
#
# Borough: 11205
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11205      0.62                 0.50
#
# Borough: 11206
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11206      0.60                 0.67
#
# Borough: 11207
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11207      0.52                 0.83
#
# Borough: 11208
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11208      0.42                 0.83
#
# Borough: 11209
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11209      0.37                 0.83
#
# Borough: 11210
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11210      0.47                 1.00
#
# Borough: 11211
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11211      0.68                 0.83
#
# Borough: 11212
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11212      0.54                 0.83
#
# Borough: 11213
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11213      0.54                 0.67
#
# Borough: 11214
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11214      0.35                 0.67
#
# Borough: 11215
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11215      0.58                 0.83
#
# Borough: 11216
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11216      0.57                 0.83
#
# Borough: 11217
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11217      0.61                 0.67
#
# Borough: 11218
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11218      0.47                 0.83
#
# Borough: 11219
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11219      0.36                 0.83
#
# Borough: 11220
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11220      0.44                 0.83
#
# Borough: 11221
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11221      0.54                 0.83
#
# Borough: 11222
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11222      0.57                 0.67
#
# Borough: 11223
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11223      0.39                 0.83
#
# Borough: 11224
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11224      0.32                 0.83
#
# Borough: 11225
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11225      0.53                 0.67
#
# Borough: 11226
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11226      0.47                 0.83
#
# Borough: 11228
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11228      0.39                 0.83
#
# Borough: 11229
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11229      0.42                 0.83
#
# Borough: 11230
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11230      0.46                 0.83
#
# Borough: 11231
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11231      0.56                 0.67
#
# Borough: 11232
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11232      0.52                 0.50
#
# Borough: 11233
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11233      0.53                 1.00
#
# Borough: 11234
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11234      0.45                 0.83
#
# Borough: 11235
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11235      0.39                 0.83
#
# Borough: 11236
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11236      0.45                 0.83
#
# Borough: 11237
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11237      0.54                 0.67
#
# Borough: 11238
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11238      0.64                 0.67
#
# Borough: 11239
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11239      0.38                 0.50
#
# Borough: 11354
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11354      0.40                 1.00
#
# Borough: 11355
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11355      0.45                 0.83
#
# Borough: 11356
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11356      0.27                 0.67
#
# Borough: 11357
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11357      0.44                 0.83
#
# Borough: 11358
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11358      0.36                 0.83
#
# Borough: 11360
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11360      0.31                 0.50
#
# Borough: 11361
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11361      0.32                 0.83
#
# Borough: 11362
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11362      0.33                 0.50
#
# Borough: 11363
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11363      0.16                 0.50
#
# Borough: 11364
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11364      0.34                 0.50
#
# Borough: 11365
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11365      0.41                 0.67
#
# Borough: 11366
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11366      0.40                 0.83
#
# Borough: 11367
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11367      0.45                 0.50
#
# Borough: 11368
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11368      0.79                 0.83
#
# Borough: 11369
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11369      0.78                 0.67
#
# Borough: 11370
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11370      0.77                 0.83
#
# Borough: 11372
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11372      0.62                 0.83
#
# Borough: 11373
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11373      0.57                 0.83
#
# Borough: 11374
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11374      0.56                 0.83
#
# Borough: 11375
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11375      0.56                 0.83
#
# Borough: 11377
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11377      0.66                 0.67
#
# Borough: 11378
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11378      0.61                 0.67
#
# Borough: 11379
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11379      0.52                 0.67
#
# Borough: 11385
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11385      0.60                 0.83
#
# Borough: 11411
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11411      0.40                 0.33
#
# Borough: 11412
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11412      0.45                 0.50
#
# Borough: 11413
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11413      0.81                 0.83
#
# Borough: 11414
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11414      0.81                 0.50
#
# Borough: 11415
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11415      0.51                 0.50
#
# Borough: 11416
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11416      0.39                 0.67
#
# Borough: 11417
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11417      0.47                 0.67
#
# Borough: 11418
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11418      0.55                 0.67
#
# Borough: 11419
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11419      0.43                 0.33
#
# Borough: 11420
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11420      0.81                 0.67
#
# Borough: 11421
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11421      0.40                 0.83
#
# Borough: 11422
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11422      0.81                 0.67
#
# Borough: 11423
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11423      0.46                 0.33
#
# Borough: 11426
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11426      0.33                 0.83
#
# Borough: 11427
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11427      0.39                 0.67
#
# Borough: 11428
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11428      0.35                 0.67
#
# Borough: 11429
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11429      0.32                 0.50
#
# Borough: 11432
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11432      0.48                 0.83
#
# Borough: 11433
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11433      0.49                 0.50
#
# Borough: 11434
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11434      0.81                 0.83
#
# Borough: 11435
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11435      0.58                 0.83
#
# Borough: 11436
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11436      0.50                 0.33
#
# Borough: 11691
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11691      0.26                 0.50
#
# Borough: 11692
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11692      0.17                 0.67
#
# Borough: 11693
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11693      0.23                 0.67
#
# Borough: 11694
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11694      0.23                 0.50
#
# Borough: 11697
# ZipCode    LivelinessScore      BusinessEnvironmentScore
# -------------------------------------------------------
# 11697      0.16                 0.33
